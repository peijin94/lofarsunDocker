# %%
import matplotlib.pyplot as plt
from lofarSun import lofarData

# %%
lofar_cleaned = lofarData.LofarDataCleaned()
lofar_cleaned.load_fits('/mnt/PROC/peijin/SB037--image.fits')
lofar_cleaned.plot_image(fov=3000)#,vmax_set=4e5)
# Out:
# 100.0063250181622
# [<Figure size 432x288 with 2 Axes>,
# ...
