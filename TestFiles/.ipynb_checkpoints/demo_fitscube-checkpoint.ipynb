# %%
import sys
sys.path.insert(1, '../pro/src') # make sure to use the code in this repo

import lofarSun
import matplotlib.dates as mdates
import datetime
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

try:
    mdates.set_epoch('0000-12-31T00:00:00')# or '1970-01-01T00:00:00')
except:
    pass
#mpl.rcParams['date.epoch']='1970-01-01T00:00:00'

# %load_ext autoreload
# %autoreload 2

# %%
#plt.rcParams.keys()

# %%
from lofarSun import BF

# %%
dataset=BF.BFcube()
dataset.load_fits('test_mini_cube.fits')

# what time is it?
mdates.num2date(dataset.time_ds[0])
# Out:
# datetime.datetime(2019, 4, 8, 6, 42, tzinfo=datetime.timezone.utc)

# %%
# set the time and frequency to do the BF imaging

freq=41.660
dtime = datetime.datetime(2019, 4, 8, 9, 47, 5, 318339, tzinfo=datetime.timezone.utc)
time=mdates.date2num(dtime)
X,Y,data_bf,x,y,Ibeam=dataset.bf_image_by_freq_time(freq,time,asecpix=20,extrap=True,interpm='cubic')
# Out:
# [153, 93]

# %%
plt.imshow(data_bf)
ax = plt.gca()
im = ax.imshow((data_bf), cmap='gist_heat',
  origin='lower',extent=[np.min(X),np.max(X),np.min(Y),np.max(Y)],vmax=1e6, vmin=1e2)
ax.set_xlabel('X (Arcsec)')
ax.set_ylabel('Y (Arcsec)')
ax.set_aspect('equal', 'box')
ax.contour(X,Y,data_bf/np.max(data_bf),levels=[0.5,0.9],colors=['deepskyblue','forestgreen'])
ax.set_title('LOFAR beamform at '+str(dtime)[0:19])
ax.plot(960*np.sin(np.arange(0,2*np.pi,0.001)),
                        960*np.cos(np.arange(0,2*np.pi,0.001)),'w')

ax.get_images()[1].set_clim([0,np.max(data_bf)])
fig_title = 'beam_at_' + str(freq) + '_' + datetime.datetime.strftime(dtime, '%Y%m%d_%H%M%S')
plt.savefig('beam_at_', dpi=300)

# %%
dataset.data_cube.shape
#(freq time beam)
# Out:
# (480, 350, 127)

# %%
dyspec=dataset.data_cube[:,:,0].T

# substract background
dyspec_new = dyspec-np.tile(np.mean(dyspec,0),(dyspec.shape[0],1))

plt.imshow(dyspec_new.T,vmin=0,vmax=1e14)

# %%
mpl.rcParams['date.epoch']="0000-12-31T00:00:00"
mdates.date2num(dtime)
# Out:
# 737157.4077004438
